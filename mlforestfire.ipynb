3.1, 4.5, 2.2, 3.1, 5.4, 1.8, 2.2, 2.2, 2.2, 1.8, 2.2, 2.2, 1.8, 4.5, 4.9, 3.1, 2.2, 3.6, 4.5, 3.6, 3.6, 6.3, 3.6, 2.7, 2.2, 4.9, 4.9, 3.6, 2.7, 2.2, 2.2, 4, 3.1, 2.2, 2.7, 3.1, 5.4, 3.6, 4.9, 7.6, 7.6, 4, 0.9, 2.7, 4, 4.9, 2.2, 2.2, 5.8, 0.9, 7.2, 2.7, 1.8, 2.7, 4.5, 2.2, 5.4, 5.4, 3.1, 3.1, 6.3, 2.7, 4, 7.6, 1.8, 1.8, 4.9, 3.6, 3.1, 4.5, 4.5, 4, 4, 3.6, 2.2, 2.2, 4.9, 4, 3.1, 5.4, 2.7, 9.4, 4.5, 3.6, 4, 4.9, 3.1, 5.8, 5.4, 4, 4.5, 4.5, 3.6, 4, 3.6, 2.2, 2.2, 2.2, 5.8, 4, 3.6, 4, 6.7, 4.9, 3.6, 1.8, 1.3, 2.7, 4, 2.2, 3.6, 1.8, 3.1, 8, 3.6, 4.5, 2.2, 8, 4, 4.9, 5.4, 4.9, 4, 3.1, 3.1, 2.7, 2.7, 4, 4.9, 8, 4.9, 4.9, 7.6, 6.3, 5.4, 0.9, 5.8, 5.4, 3.6, 9.4, 5.8, 4, 4, 3.1, 2.7, 9.4, 1.3, 4, 4.5, 4.9, 4.5, 4.9, 5.8, 5.4, 4, 3.6, 6.3, 3.6, 7.6, 1.3, 4, 4.5, 2.2, 4.5, 4.9, 2.2, 3.1, 2.2, 2.7, 4.9, 4.9, 4.9, 4.9, 4.9, 4.9, 1.8, 8.5, 3.6, 3.6, 7.6, 5.4, 2.7, 2.7, 5.8, 6.7, 4, 4.5]).reshape(512,1)

wind_test=np.array([6.7, 0.9, 1.3, 4, 1.8 ]).reshape(5,1)

# %%
c1=np.array([1 for i in range(512)]).reshape(512,1)

c2=np.array([1 for i in range(5)]).reshape(5,1)

x_train=np.concatenate([c1,X,Y],axis=1) # used for training

x_test=np.concatenate([c2,X_test,Y_test],axis=1) #used for testing

print(x_train)
print(x_test)
# Out:
# [[1 8 6]
#  [1 8 6]
#  [1 8 6]
#  ...
#  [1 7 4]
#  [1 1 4]
#  [1 6 3]]
# [[1 7 5]
#  [1 7 4]
#  [1 7 4]
#  [1 8 6]
#  [1 8 6]]

# %%
from numpy.linalg import lstsq
THETA_LS=lstsq(x_train,wind)[0]
print(THETA_LS)
# Out:
# [[ 4.14257455]
#  [ 0.04041585]
#  [-0.07036699]]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,wind)



y_predict=model.predict(x_test)
print(np.shape(y_predict))
print(y_predict)
# Out:
# (5, 1)
# [[4.07365055]
#  [4.14401755]
#  [4.14401755]
#  [4.04369941]
#  [4.04369941]]

# %%
model.score(x_test,wind_test)
# Out:
# -0.30471099193016293
